# %%
from rag_helper import RAGBase
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from groq import Groq
import os

# %%
groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))
documents = load_faq_data()
index = build_index(documents)

# %%
assistant = RAGBase(
    index=index,
    llm_client=groq_client,
)

answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# The answer to your question "I just discovered the course. Can I join now?" is: **Yes**.
#
# You can join the course at any time, and you can start learning and submitting homework without registering. The course materials, including videos and GitHub resources, are available, and you can follow the weekly workflow at your own pace. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted.

# %%
custom_instructions = """
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

assistant = RAGBase(
    index=index,
    llm_client=groq_client,
    instructions=custom_instructions,
)

# %%
assistant.rag("How do I get a certificate?")
# Out:
# 'To get a certificate, you need to:\n\n1. **Finish the course with a "live" cohort**: Certificates are only awarded to students who complete the course with a live cohort, not in self-paced mode.\n2. **Pass the Capstone project**: You need to pass the Capstone project to get a certificate. \n3. **Peer-review 3 capstones**: As part of the course, you need to peer-review 3 capstone projects after submitting your own project, which can only be done during the course with a live cohort.\n\nAdditionally, make sure your **display name** and **official name** are up to date in your course profile. Your official name will appear on your certificate, so ensure it\'s accurate and matches your identification documents. \n\nIf you have any specific concerns or questions, feel free to ask!'

# %%
assistant.rag("Can I still join the course after it started?")
# Out:
# '**Yes, you can still join the course after it started.** \n\nHowever, to receive a certificate, you need to submit your project while submissions are still being accepted. Additionally, keep in mind that you can only get a certificate if you finish the course with a "live" cohort, and peer-reviewing projects is a required step that can only be done during the course runtime. \n\nTo get started, refer to the course materials: [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp). \n\nYou can follow the weekly workflow:\n1. Watch lesson videos.\n2. Work through lesson notebooks/code.\n3. Read homework instructions on GitHub.\n4. Submit answers through the course platform before the deadline. \n\nIt\'s recommended to start as soon as possible to catch up with the course material and deadlines.'
